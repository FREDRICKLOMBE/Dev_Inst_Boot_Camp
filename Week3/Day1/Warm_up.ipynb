# %%
x = 4
y = 17
s = "life"
print(s)
x = "bug"
print(s*x)

def myfun(var):
    print("fun")
    print(var)
    return var * 2

print(myfun(s))
# Out:
# life
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 print(s)
#       5 x = "bug"
# ----> 6 print(s*x)
#       8 def myfun(var):
#       9     print("fun")
#
# TypeError: can't multiply sequence by non-int of type 'str'
